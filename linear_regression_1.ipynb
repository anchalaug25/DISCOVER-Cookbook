# %% [markdown]
# <a href="https://colab.research.google.com/github/anchalaug25/DISCOVER-Cookbook/blob/main/linear_regression_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#doing from own
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-92a8381f-f785-41fd-a030-39aa6d38a24a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92a8381f-f785-41fd-a030-39aa6d38a24a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("house_prices_square_footage.csv")

# %%
df.head()
# Out:
#    Square Footage  House Price
# 0             800       150000
# 1             900       170000
# 2            1000       180000
# 3            1100       200000
# 4            1200       220000

# %%
plt.scatter(df["Square Footage"],df["House Price"],color="purple")
plt.xlabel("sq feet")
plt.ylabel("house prediction")
# Out:
# Text(0, 0.5, 'house prediction')

# %%
x=df.iloc[:,0] #the first : mean it will select all rows and 0:1 means selecting columns frm 0 to 1 ,here 0 is not given
x
# Out:
# 0     800
# 1     900
# 2    1000
# 3    1100
# 4    1200
# 5    1300
# 6    1400
# 7    1500
# Name: Square Footage, dtype: int64

# %%
y=df.iloc[:,1] # -1 refers to selecting the last column
y
# Out:
# 0    150000
# 1    170000
# 2    180000
# 3    200000
# 4    220000
# 5    240000
# 6    250000
# 7    270000
# Name: House Price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
# Convert x to a DataFrame with a single column
x = df.iloc[:, 0].values.reshape(-1, 1)
y = df.iloc[:, 1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
# array([[1200],
#        [ 900],
#        [1400]])

# %%
y_test
# Out:
# 4    220000
# 1    170000
# 6    250000
# Name: House Price, dtype: int64

# %%
lr.predict(x_test[0].reshape(1,1)) # Use integer-based indexing for NumPy arrays
# Out:
# array([218561.64383562])

# %%
lr.predict(x_test[1].reshape(1,1))
# Out:
# array([165753.42465753])

# %%
plt.scatter(df['Square Footage'], df['House Price'])
plt.plot(x_test, lr.predict(x_test),color="red") # jo red line h wo best fit line hai.
plt.xlabel('Square Footage')
plt.ylabel('House Price')
# Out:
# Text(0, 0.5, 'House Price')

# %%
m=lr.coef_
m # m yha p y=mx+b wla h
# Out:
# array([176.02739726])

# %%
b=lr.intercept_
b
# Out:
# 7328.767123287718
